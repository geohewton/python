# %%
import numpy as np

# %%
1+1
# Out:
# 2

# %% [markdown]
# ## This code adds **one plus one**.

# %%
2*2
# Out:
# 4

# %%
2+3
# Out:
# 5

# %%
bool
# Out:
# bool

# %%
10>3
# Out:
# True

# %%
10<3
# Out:
# False

# %%
10 // 3
# Out:
# 3

# %%
10/3
# Out:
# 3.3333333333333335

# %%
2**3
# Out:
# 8

# %%
2+3
# Out:
# 5

# %%
2*3
# Out:
# 6

# %%
2**3
# Out:
# 8

# %%
2-3
# Out:
# -1

# %%
2/3
# Out:
# 0.6666666666666666

# %%
10**3
# Out:
# 1000

# %%
10%3
# Out:
# 1

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10%3
# Out:
# 1

# %%
10//3
# Out:
# 3

# %%
10 == 3
# Out:
# False

# %%
10 != 3
# Out:
# True

# %%
10 + 3 * 2
# Out:
# 16

# %%
(10+3)*2
# Out:
# 26

# %%
degrees_celsius = 25

# %%
degreesCelsius = 25

# %%
degrees_celsius
# Out:
# 25

# %%
degrees_celsius == 25
# Out:
# True

# %%
degrees_celsius != 25
# Out:
# False

# %%
degrees_celsius != 24
# Out:
# True

# %%
degrees_fahrenheit = (9/5)*degrees_celsius+32

# %%
degrees_fahrenheit
# Out:
# 77.0

# %%
degrees_celsius = 35

# %%
degrees_celsius
# Out:
# 35

# %%
degrees_celsius = degrees_celsius +10

# %%
degrees_celsius
# Out:
# 45

# %%
degrees_celsius += 10

# %%
degrees_celsius
# Out:
# 55

# %%
degrees_celsius
# Out:
# 55

# %% [markdown]
# # Exercise

# %%
name = 'Meghan'
age = 39
favourite_num = 13

# %%
name
# Out:
# 'Meghan'

# %%
age
# Out:
# 39

# %%
age != favourite_num
# Out:
# True

# %%
age + 10
# Out:
# 49

# %%
age += 10

# %%
age
# Out:
# 49

# %%
age -=10

# %%
age
# Out:
# 39

# %%
age
# Out:
# 39

# %%
age += 10

# %%
age
# Out:
# 49

# %%
age
# Out:
# 49

# %%
age -= 10

# %%
age
# Out:
# 39

# %%
print(name)
# Out:
# Meghan

# %%
print(name)
print(age)
print(favourite_num)
# Out:
# Meghan
# 39
# 13

# %%
student1_grade = 90
student2_grade = 50
student3_grade = 74

average_grade = (student1_grade+student2_grade+student3_grade)/3
#This is the average grade of the class.

# %%
average_grade
# Out:
# 71.33333333333333

# %%
abs(-42)
# Out:
# 42

# %%
round(32.5)
# Out:
# 32

# %%
round(3.14159,2)
# Out:
# 3.14

# %%
int(3.6)
# Out:
# 3

# %%
float(5)
# Out:
# 5.0

# %%
help(abs)
# Out:
# Help on built-in function abs in module builtins:
#
# abs(x, /)
#     Return the absolute value of the argument.

# %%
def c_to_f(degrees_celsius):
    #convert degs C to degs F
    return (degrees_celsius*(9/5) + 32)

# %%
c_to_f(-10)
# Out:
# 14.0

# %%
freezing_point_f = c_to_f(0)

# %%
freezing_point_f
# Out:
# 32.0

# %%
c_to_f(100)
# Out:
# 212.0

# %%
c_to_f(-100)
# Out:
# -148.0

# %%
def anagram_checker(word_a, word_b):
  return sorted(word_a.lower()) == sorted(word_b.lower())
  # Your code here

# Run your code to check using the words below:
anagram_checker("Silent", "listen")
# Out:
# True

# %%
anagram_checker("Night","Silent")
# Out:
# False

# %%
anagram_checker("Banana","Bandana")
# Out:
# False

# %%
anagram_checker("Night","Thing")
# Out:
# True

# %%
randomword = "Shetland"

# %%
sorted(randomword)
# Out:
# ['S', 'a', 'd', 'e', 'h', 'l', 'n', 't']

# %%
def anagram_checker(word_a, word_b, is_case_sensitive):
  return sorted(word_a) == sorted(word_b)

anagram_checker("Silent","listen", is_case_sensitive=True)
# Out:
# False

# %%
anagram_checker("Night","thiNg", True)
# Out:
# True

# %%
anagram_checker("Fired","Fried", True)
# Out:
# True
